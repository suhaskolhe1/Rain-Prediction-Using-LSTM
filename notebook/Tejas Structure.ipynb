# %%
import numpy as np
import pandas as pd
from pathlib import Path
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn.metrics import accuracy_score, classification_report
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Input
from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt
from imblearn.over_sampling import SMOTE
from sklearn.impute import SimpleImputer
# Constants
SEQUENCE_LENGTH = 5
BATCH_SIZE = 32
EPOCHS = 100
VALIDATION_SPLIT = 0.1
PATIENCE = 7
CSV_PATH = Path("E:/IDE/Python/PythonProject/Rain/Rain-Prediction-Using-LSTM/notebook/data/processed/final_dataset.csv")

# Load and preprocess data
def load_and_preprocess_data(csv_path):
    """
    Loads and preprocesses weather data from a CSV file.
    """
    data = pd.read_csv(csv_path)

    # Handle missing values with forward fill, then backward fill for any remaining
    data.ffill(inplace=True)
    data.bfill(inplace=True)

    # Encode WindGustDir (categorical) → numeric
    wind_dir_encoder = LabelEncoder()
    data['WindGustDir'] = wind_dir_encoder.fit_transform(data['WindGustDir'].astype(str))

    # Drop rows where RainTomorrow is missing
    data.dropna(subset=['RainTomorrow'], inplace=True)
    data['RainTomorrow'] = data['RainTomorrow'].map({'No': 0, 'Yes': 1})

    # Define features and target
    features = ['MinTemp', 'MaxTemp', 'WindGustDir', 'WindGustSpeed', 'Humidity', 'Pressure', 'Temp']
    target = 'RainTomorrow'

    X = data[features]
    y = data[target]

    # Impute any remaining missing values with mean (safe before SMOTE)
    imputer = SimpleImputer(strategy="mean")
    X = pd.DataFrame(imputer.fit_transform(X), columns=features)

    # Apply SMOTE
    print("Original dataset shape:", y.shape)
    print("Original dataset distribution:\n", pd.Series(y).value_counts())
    smote = SMOTE(random_state=42)
    X_resampled, y_resampled = smote.fit_resample(X, y)
    print("\nResampled dataset shape:", y_resampled.shape)
    print("Resampled dataset distribution:\n", pd.Series(y_resampled).value_counts())

    # Scale features
    scaler = MinMaxScaler()
    X_scaled = scaler.fit_transform(X_resampled)

    return X_scaled, y_resampled.values, features, scaler, wind_dir_encoder

# Create sequences for LSTM
def create_sequences(X, y, seq_len=SEQUENCE_LENGTH):
    """
    Creates sequences of data for the LSTM model.

    Args:
        X (np.ndarray): Features data.
        y (np.ndarray): Target values.
        seq_len (int): The length of each sequence.

    Returns:
        tuple: A tuple containing:
            - X_seq (np.ndarray): Feature sequences.
            - y_seq (np.ndarray): Target values for each sequence.
    """
    X_seq = [X[i:i+seq_len] for i in range(len(X) - seq_len)]
    y_seq = [y[i+seq_len] for i in range(len(X) - seq_len)]
    return np.array(X_seq), np.array(y_seq)


# Build the LSTM model
def build_lstm_model(input_shape):
    """
    Builds a Sequential LSTM model.

    Args:
        input_shape (tuple): The shape of the input sequences (sequence_length, num_features).

    Returns:
        tensorflow.keras.models.Sequential: The built LSTM model.
    """
    model = Sequential([
        Input(shape=input_shape), # Use Input layer to specify input shape
        LSTM(128, return_sequences=True),
        Dropout(0.3),
        LSTM(128, return_sequences=True),
        Dropout(0.2),
        LSTM(32),
        Dropout(0.2),
        Dense(1, activation='sigmoid')
    ])
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

# Plot training history
def plot_history(history):
    """
    Plots the training and validation accuracy and loss history.

    Args:
        history (tensorflow.keras.callbacks.History): The training history object.
    """
    plt.figure(figsize=(12, 6))
    for i, metric in enumerate(['accuracy', 'loss']):
        plt.subplot(1, 2, i + 1)
        plt.plot(history.history[metric], label=f'Train {metric.capitalize()}')
        plt.plot(history.history[f'val_{metric}'], label=f'Val {metric.capitalize()}')
        plt.title(f'Model {metric.capitalize()}')
        plt.xlabel('Epoch')
        plt.ylabel(metric.capitalize())
        plt.legend()
    plt.tight_layout()
    plt.show()

# Predict for current weather
def predict_current_weather(model, scaler, encoder, current_data, last_sequence, features):
    """
    Predicts the probability of rain tomorrow for the current weather data.

    Args:
        model (tensorflow.keras.models.Sequential): The trained LSTM model.
        scaler (MinMaxScaler): The fitted MinMaxScaler object.
        encoder (LabelEncoder): The fitted LabelEncoder object for WindGustDir.
        current_data (dict): A dictionary containing the current weather data.
        last_sequence (np.ndarray): The last sequence from the training data for context.
        features (list): List of feature names.

    Returns:
        float: The predicted probability of rain tomorrow.
    """
    # Ensure WindGustDir is encoded if it's a string
    if isinstance(current_data['WindGustDir'], str):
        current_data['WindGustDir'] = encoder.transform([current_data['WindGustDir']])[0]
    elif isinstance(current_data['WindGustDir'], (int, np.integer)):
        # If it's already encoded, keep it as is.
        pass
    else:
        # Handle unexpected types if necessary
        raise TypeError("WindGustDir must be a string or encoded integer.")


    df = pd.DataFrame([current_data], columns=features)
    current_scaled = scaler.transform(df)

    # Create the sequence for prediction
    sequence = np.copy(last_sequence)
    sequence[:-1] = sequence[1:] # Shift existing sequence data
    sequence[-1] = current_scaled[0] # Add current weather data to the end

    sequence = sequence.reshape(1, SEQUENCE_LENGTH, len(features))

    return model.predict(sequence, verbose=0)[0][0]

# Main execution
X_scaled, y, features, scaler, encoder = load_and_preprocess_data(CSV_PATH)
X_seq, y_seq = create_sequences(X_scaled, y)

# Split the data with shuffling to ensure both classes are in the test set
X_train, X_test, y_train, y_test = train_test_split(X_seq, y_seq, test_size=0.2, random_state=42, shuffle=True, stratify=y_seq)


model = build_lstm_model(input_shape=(SEQUENCE_LENGTH, len(features)))
model.summary()

early_stop = EarlyStopping(monitor='val_loss', patience=PATIENCE, restore_best_weights=True)
history = model.fit(
    X_train, y_train,
    validation_split=VALIDATION_SPLIT,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    callbacks=[early_stop],
    verbose=1
)

# Evaluation
y_pred = (model.predict(X_test, verbose=0) > 0.5).astype(int)
print("\nModel Evaluation:")
print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:")
# Handle zero division in classification report
print(classification_report(y_test, y_pred, zero_division=0))


# Plot training history
plot_history(history)

# Predict for a sample current weather
current_weather = {
    'MinTemp': 15.2,
    'MaxTemp': 25.1,
    'WindGustDir': 'E', # Keep as string for demonstration
    'WindGustSpeed': 46,
    'Humidity': 42,
    'Pressure': 1015,
    'Temp': 23.9
}

# Use last SEQUENCE_LENGTH rows of the original scaled data to form initial context for prediction
# Note: It's generally better to use a sliding window approach for real-time predictions
# where you maintain the last SEQUENCE_LENGTH actual weather observations.
# For this example, we'll use the last part of the preprocessed data as context.
last_sequence_context = X_scaled[len(X_scaled) - len(X_seq) - SEQUENCE_LENGTH : len(X_scaled) - len(X_seq)]


rain_prob = predict_current_weather(model, scaler, encoder, current_weather, last_sequence_context, features)


print(f"\nProbability of rain tomorrow: {rain_prob:.2%}")
print("Prediction:", "It will rain tomorrow" if rain_prob > 0.5 else "It will NOT rain tomorrow")
# Out:
# Original dataset shape: (5702,)
# Original dataset distribution:
#  RainTomorrow
# 0    3509
# 1    2193
# Name: count, dtype: int64
#
# Resampled dataset shape: (7018,)
# Resampled dataset distribution:
#  RainTomorrow
# 0    3509
# 1    3509
# Name: count, dtype: int64
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 5, 128)            69632
#
#  dropout (Dropout)           (None, 5, 128)            0
#
#  lstm_1 (LSTM)               (None, 5, 128)            131584
#
#  dropout_1 (Dropout)         (None, 5, 128)            0
#
#  lstm_2 (LSTM)               (None, 32)                20608
#
#  dropout_2 (Dropout)         (None, 32)                0
#
#  dense (Dense)               (None, 1)                 33
#
# =================================================================
# Total params: 221,857
# Trainable params: 221,857
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 158/158 [==============================] - 10s 21ms/step - loss: 0.3831 - accuracy: 0.8526 - val_loss: 0.2818 - val_accuracy: 0.8984
# Epoch 2/100
# 158/158 [==============================] - 3s 16ms/step - loss: 0.3206 - accuracy: 0.8869 - val_loss: 0.2720 - val_accuracy: 0.9073
# Epoch 3/100
# 158/158 [==============================] - 2s 15ms/step - loss: 0.3114 - accuracy: 0.8921 - val_loss: 0.2770 - val_accuracy: 0.9037
# Epoch 4/100
# 158/158 [==============================] - 3s 20ms/step - loss: 0.2998 - accuracy: 0.8944 - val_loss: 0.2783 - val_accuracy: 0.9037
# Epoch 5/100
# 158/158 [==============================] - 4s 24ms/step - loss: 0.2966 - accuracy: 0.8944 - val_loss: 0.2532 - val_accuracy: 0.9127
# Epoch 6/100
# 158/158 [==============================] - 3s 19ms/step - loss: 0.2925 - accuracy: 0.8994 - val_loss: 0.2641 - val_accuracy: 0.9091
# Epoch 7/100
# 158/158 [==============================] - 3s 18ms/step - loss: 0.2945 - accuracy: 0.8968 - val_loss: 0.2437 - val_accuracy: 0.9198
# Epoch 8/100
# 158/158 [==============================] - 3s 19ms/step - loss: 0.2852 - accuracy: 0.9018 - val_loss: 0.2417 - val_accuracy: 0.9251
# Epoch 9/100
# 158/158 [==============================] - 3s 19ms/step - loss: 0.2832 - accuracy: 0.9000 - val_loss: 0.2461 - val_accuracy: 0.9269
# Epoch 10/100
# 158/158 [==============================] - 3s 19ms/step - loss: 0.2774 - accuracy: 0.9010 - val_loss: 0.2582 - val_accuracy: 0.9287
# Epoch 11/100
# 158/158 [==============================] - 3s 18ms/step - loss: 0.2771 - accuracy: 0.9045 - val_loss: 0.2500 - val_accuracy: 0.9216
# Epoch 12/100
# 158/158 [==============================] - 3s 16ms/step - loss: 0.2728 - accuracy: 0.9031 - val_loss: 0.2535 - val_accuracy: 0.9144
# Epoch 13/100
# 158/158 [==============================] - 3s 17ms/step - loss: 0.2705 - accuracy: 0.9033 - val_loss: 0.2327 - val_accuracy: 0.9251
# Epoch 14/100
# 158/158 [==============================] - 4s 28ms/step - loss: 0.2665 - accuracy: 0.9041 - val_loss: 0.2397 - val_accuracy: 0.9216
# Epoch 15/100
# 158/158 [==============================] - 4s 23ms/step - loss: 0.2633 - accuracy: 0.9053 - val_loss: 0.2310 - val_accuracy: 0.9269
# Epoch 16/100
# 158/158 [==============================] - 3s 20ms/step - loss: 0.2638 - accuracy: 0.9049 - val_loss: 0.2268 - val_accuracy: 0.9234
# Epoch 17/100
# 158/158 [==============================] - 3s 19ms/step - loss: 0.2588 - accuracy: 0.9075 - val_loss: 0.2252 - val_accuracy: 0.9234
# Epoch 18/100
# 158/158 [==============================] - 3s 17ms/step - loss: 0.2539 - accuracy: 0.9059 - val_loss: 0.2302 - val_accuracy: 0.9216
# Epoch 19/100
# 158/158 [==============================] - 3s 17ms/step - loss: 0.2554 - accuracy: 0.9059 - val_loss: 0.2202 - val_accuracy: 0.9234
# Epoch 20/100
# 158/158 [==============================] - 3s 17ms/step - loss: 0.2526 - accuracy: 0.9079 - val_loss: 0.2198 - val_accuracy: 0.9251
# Epoch 21/100
# 158/158 [==============================] - 3s 16ms/step - loss: 0.2486 - accuracy: 0.9089 - val_loss: 0.2206 - val_accuracy: 0.9234
# Epoch 22/100
# 158/158 [==============================] - 2s 14ms/step - loss: 0.2490 - accuracy: 0.9079 - val_loss: 0.2315 - val_accuracy: 0.9198
# Epoch 23/100
# 158/158 [==============================] - 2s 15ms/step - loss: 0.2471 - accuracy: 0.9075 - val_loss: 0.2182 - val_accuracy: 0.9251
# Epoch 24/100
# 158/158 [==============================] - 2s 15ms/step - loss: 0.2485 - accuracy: 0.9081 - val_loss: 0.2178 - val_accuracy: 0.9234
# Epoch 25/100
# 158/158 [==============================] - 2s 15ms/step - loss: 0.2448 - accuracy: 0.9087 - val_loss: 0.2220 - val_accuracy: 0.9234
# Epoch 26/100
# 158/158 [==============================] - 3s 16ms/step - loss: 0.2476 - accuracy: 0.9079 - val_loss: 0.2177 - val_accuracy: 0.9269
# Epoch 27/100
# 158/158 [==============================] - 2s 14ms/step - loss: 0.2460 - accuracy: 0.9097 - val_loss: 0.2199 - val_accuracy: 0.9234
# Epoch 28/100
# 158/158 [==============================] - 2s 14ms/step - loss: 0.2433 - accuracy: 0.9103 - val_loss: 0.2268 - val_accuracy: 0.9234
# Epoch 29/100
# 158/158 [==============================] - 2s 15ms/step - loss: 0.2438 - accuracy: 0.9097 - val_loss: 0.2204 - val_accuracy: 0.9234
# Epoch 30/100
# 158/158 [==============================] - 2s 14ms/step - loss: 0.2457 - accuracy: 0.9093 - val_loss: 0.2200 - val_accuracy: 0.9234
# Epoch 31/100
# 158/158 [==============================] - 3s 17ms/step - loss: 0.2441 - accuracy: 0.9121 - val_loss: 0.2294 - val_accuracy: 0.9216
# Epoch 32/100
# 158/158 [==============================] - 3s 18ms/step - loss: 0.2423 - accuracy: 0.9099 - val_loss: 0.2184 - val_accuracy: 0.9216
# Epoch 33/100
# 158/158 [==============================] - 3s 18ms/step - loss: 0.2354 - accuracy: 0.9117 - val_loss: 0.2279 - val_accuracy: 0.9251
#
# Model Evaluation:
# Accuracy: 0.9287241625089094
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.92      0.94      0.93       701
#            1       0.94      0.91      0.93       702
#
#     accuracy                           0.93      1403
#    macro avg       0.93      0.93      0.93      1403
# weighted avg       0.93      0.93      0.93      1403
# Probability of rain tomorrow: 5.60%
# Prediction: It will NOT rain tomorrow

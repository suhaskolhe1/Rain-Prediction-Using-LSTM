# %%
import numpy as np
import pandas as pd
from pathlib import Path
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn.metrics import accuracy_score, classification_report
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Input
from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt
from imblearn.over_sampling import SMOTE
from sklearn.impute import SimpleImputer
# Constants
SEQUENCE_LENGTH = 5
BATCH_SIZE = 32
EPOCHS = 100
VALIDATION_SPLIT = 0.1
PATIENCE = 7
CSV_PATH = Path("E:/IDE/Python/PythonProject/Rain/Rain-Prediction-Using-LSTM/notebook/data/processed/final_dataset.csv")

# Load and preprocess data
def load_and_preprocess_data(csv_path):
    """
    Loads and preprocesses weather data from a CSV file.
    """
    data = pd.read_csv(csv_path)

    # Handle missing values with forward fill, then backward fill for any remaining
    data.ffill(inplace=True)
    data.bfill(inplace=True)

    # Encode WindGustDir (categorical) → numeric
    wind_dir_encoder = LabelEncoder()
    data['WindGustDir'] = wind_dir_encoder.fit_transform(data['WindGustDir'].astype(str))

    # Drop rows where RainTomorrow is missing
    data.dropna(subset=['RainTomorrow'], inplace=True)
    data['RainTomorrow'] = data['RainTomorrow'].map({'No': 0, 'Yes': 1})

    # Define features and target
    features = ['MinTemp', 'MaxTemp', 'WindGustDir', 'WindGustSpeed', 'Humidity', 'Pressure', 'Temp']
    target = 'RainTomorrow'

    X = data[features]
    y = data[target]

    # Impute any remaining missing values with mean (safe before SMOTE)
    imputer = SimpleImputer(strategy="mean")
    X = pd.DataFrame(imputer.fit_transform(X), columns=features)

    # Apply SMOTE
    print("Original dataset shape:", y.shape)
    print("Original dataset distribution:\n", pd.Series(y).value_counts())
    smote = SMOTE(random_state=42)
    X_resampled, y_resampled = smote.fit_resample(X, y)
    print("\nResampled dataset shape:", y_resampled.shape)
    print("Resampled dataset distribution:\n", pd.Series(y_resampled).value_counts())

    # Scale features
    scaler = MinMaxScaler()
    X_scaled = scaler.fit_transform(X_resampled)

    return X_scaled, y_resampled.values, features, scaler, wind_dir_encoder

# Create sequences for LSTM
def create_sequences(X, y, seq_len=SEQUENCE_LENGTH):
    """
    Creates sequences of data for the LSTM model.

    Args:
        X (np.ndarray): Features data.
        y (np.ndarray): Target values.
        seq_len (int): The length of each sequence.

    Returns:
        tuple: A tuple containing:
            - X_seq (np.ndarray): Feature sequences.
            - y_seq (np.ndarray): Target values for each sequence.
    """
    X_seq = [X[i:i+seq_len] for i in range(len(X) - seq_len)]
    y_seq = [y[i+seq_len] for i in range(len(X) - seq_len)]
    return np.array(X_seq), np.array(y_seq)


# Build the LSTM model
def build_lstm_model(input_shape):
    """
    Builds a Sequential LSTM model.

    Args:
        input_shape (tuple): The shape of the input sequences (sequence_length, num_features).

    Returns:
        tensorflow.keras.models.Sequential: The built LSTM model.
    """
    model = Sequential([
        Input(shape=input_shape), # Use Input layer to specify input shape
        LSTM(128, return_sequences=True),
        Dropout(0.3),
        LSTM(128, return_sequences=True),
        Dropout(0.2),
        LSTM(32),
        Dropout(0.2),
        Dense(1, activation='sigmoid')
    ])
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

# Plot training history
def plot_history(history):
    """
    Plots the training and validation accuracy and loss history.

    Args:
        history (tensorflow.keras.callbacks.History): The training history object.
    """
    plt.figure(figsize=(12, 6))
    for i, metric in enumerate(['accuracy', 'loss']):
        plt.subplot(1, 2, i + 1)
        plt.plot(history.history[metric], label=f'Train {metric.capitalize()}')
        plt.plot(history.history[f'val_{metric}'], label=f'Val {metric.capitalize()}')
        plt.title(f'Model {metric.capitalize()}')
        plt.xlabel('Epoch')
        plt.ylabel(metric.capitalize())
        plt.legend()
    plt.tight_layout()
    plt.show()

# Predict for current weather
def predict_current_weather(model, scaler, encoder, current_data, last_sequence, features):
    """
    Predicts the probability of rain tomorrow for the current weather data.

    Args:
        model (tensorflow.keras.models.Sequential): The trained LSTM model.
        scaler (MinMaxScaler): The fitted MinMaxScaler object.
        encoder (LabelEncoder): The fitted LabelEncoder object for WindGustDir.
        current_data (dict): A dictionary containing the current weather data.
        last_sequence (np.ndarray): The last sequence from the training data for context.
        features (list): List of feature names.

    Returns:
        float: The predicted probability of rain tomorrow.
    """
    # Ensure WindGustDir is encoded if it's a string
    if isinstance(current_data['WindGustDir'], str):
        current_data['WindGustDir'] = encoder.transform([current_data['WindGustDir']])[0]
    elif isinstance(current_data['WindGustDir'], (int, np.integer)):
        # If it's already encoded, keep it as is.
        pass
    else:
        # Handle unexpected types if necessary
        raise TypeError("WindGustDir must be a string or encoded integer.")


    df = pd.DataFrame([current_data], columns=features)
    current_scaled = scaler.transform(df)

    # Create the sequence for prediction
    sequence = np.copy(last_sequence)
    sequence[:-1] = sequence[1:] # Shift existing sequence data
    sequence[-1] = current_scaled[0] # Add current weather data to the end

    sequence = sequence.reshape(1, SEQUENCE_LENGTH, len(features))

    return model.predict(sequence, verbose=0)[0][0]

# Main execution
X_scaled, y, features, scaler, encoder = load_and_preprocess_data(CSV_PATH)
X_seq, y_seq = create_sequences(X_scaled, y)

# Split the data with shuffling to ensure both classes are in the test set
X_train, X_test, y_train, y_test = train_test_split(X_seq, y_seq, test_size=0.2, random_state=42, shuffle=True, stratify=y_seq)


model = build_lstm_model(input_shape=(SEQUENCE_LENGTH, len(features)))
model.summary()

early_stop = EarlyStopping(monitor='val_loss', patience=PATIENCE, restore_best_weights=True)
history = model.fit(
    X_train, y_train,
    validation_split=VALIDATION_SPLIT,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    callbacks=[early_stop],
    verbose=1
)

# Evaluation
y_pred = (model.predict(X_test, verbose=0) > 0.5).astype(int)
print("\nModel Evaluation:")
print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:")
# Handle zero division in classification report
print(classification_report(y_test, y_pred, zero_division=0))


# Plot training history
plot_history(history)

# Predict for a sample current weather
current_weather = {
    'MinTemp': 15.2,
    'MaxTemp': 25.1,
    'WindGustDir': 'E', # Keep as string for demonstration
    'WindGustSpeed': 46,
    'Humidity': 42,
    'Pressure': 1015,
    'Temp': 23.9
}

# Use last SEQUENCE_LENGTH rows of the original scaled data to form initial context for prediction
# Note: It's generally better to use a sliding window approach for real-time predictions
# where you maintain the last SEQUENCE_LENGTH actual weather observations.
# For this example, we'll use the last part of the preprocessed data as context.
last_sequence_context = X_scaled[len(X_scaled) - len(X_seq) - SEQUENCE_LENGTH : len(X_scaled) - len(X_seq)]


rain_prob = predict_current_weather(model, scaler, encoder, current_weather, last_sequence_context, features)


print(f"\nProbability of rain tomorrow: {rain_prob:.2%}")
print("Prediction:", "It will rain tomorrow" if rain_prob > 0.5 else "It will NOT rain tomorrow")
# Out:
# Original dataset shape: (5702,)
# Original dataset distribution:
#  RainTomorrow
# 0    3509
# 1    2193
# Name: count, dtype: int64
#
# Resampled dataset shape: (7018,)
# Resampled dataset distribution:
#  RainTomorrow
# 0    3509
# 1    3509
# Name: count, dtype: int64
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_6 (LSTM)               (None, 10, 128)           69632
#
#  dropout_6 (Dropout)         (None, 10, 128)           0
#
#  lstm_7 (LSTM)               (None, 10, 128)           131584
#
#  dropout_7 (Dropout)         (None, 10, 128)           0
#
#  lstm_8 (LSTM)               (None, 32)                20608
#
#  dropout_8 (Dropout)         (None, 32)                0
#
#  dense_2 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 221857 (866.63 KB)
# Trainable params: 221857 (866.63 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/100
# 158/158 [==============================] - 17s 63ms/step - loss: 0.3585 - accuracy: 0.8747 - val_loss: 0.3138 - val_accuracy: 0.8966
# Epoch 2/100
# 158/158 [==============================] - 5s 31ms/step - loss: 0.3289 - accuracy: 0.8864 - val_loss: 0.3091 - val_accuracy: 0.8984
# Epoch 3/100
# 158/158 [==============================] - 5s 29ms/step - loss: 0.3195 - accuracy: 0.8924 - val_loss: 0.2907 - val_accuracy: 0.8984
# Epoch 4/100
# 158/158 [==============================] - 5s 33ms/step - loss: 0.3086 - accuracy: 0.8953 - val_loss: 0.2851 - val_accuracy: 0.9020
# Epoch 5/100
# 158/158 [==============================] - 6s 38ms/step - loss: 0.3028 - accuracy: 0.8945 - val_loss: 0.2786 - val_accuracy: 0.8984
# Epoch 6/100
# 158/158 [==============================] - 6s 41ms/step - loss: 0.3030 - accuracy: 0.8973 - val_loss: 0.2835 - val_accuracy: 0.9055
# Epoch 7/100
# 158/158 [==============================] - 7s 42ms/step - loss: 0.2933 - accuracy: 0.8973 - val_loss: 0.2668 - val_accuracy: 0.8984
# Epoch 8/100
# 158/158 [==============================] - 7s 42ms/step - loss: 0.2883 - accuracy: 0.9013 - val_loss: 0.2577 - val_accuracy: 0.9091
# Epoch 9/100
# 158/158 [==============================] - 5s 33ms/step - loss: 0.2838 - accuracy: 0.9033 - val_loss: 0.2970 - val_accuracy: 0.9002
# Epoch 10/100
# 158/158 [==============================] - 5s 34ms/step - loss: 0.2803 - accuracy: 0.9035 - val_loss: 0.2509 - val_accuracy: 0.9091
# Epoch 11/100
# 158/158 [==============================] - 9s 57ms/step - loss: 0.2744 - accuracy: 0.9031 - val_loss: 0.2536 - val_accuracy: 0.9091
# Epoch 12/100
# 158/158 [==============================] - 9s 57ms/step - loss: 0.2726 - accuracy: 0.9041 - val_loss: 0.2526 - val_accuracy: 0.9091
# Epoch 13/100
# 158/158 [==============================] - 7s 44ms/step - loss: 0.2759 - accuracy: 0.9025 - val_loss: 0.2436 - val_accuracy: 0.9144
# Epoch 14/100
# 158/158 [==============================] - 5s 29ms/step - loss: 0.2650 - accuracy: 0.9033 - val_loss: 0.2493 - val_accuracy: 0.9162
# Epoch 15/100
# 158/158 [==============================] - 5s 31ms/step - loss: 0.2624 - accuracy: 0.9056 - val_loss: 0.2449 - val_accuracy: 0.9144
# Epoch 16/100
# 158/158 [==============================] - 5s 29ms/step - loss: 0.2607 - accuracy: 0.9045 - val_loss: 0.2376 - val_accuracy: 0.9305
# Epoch 17/100
# 158/158 [==============================] - 5s 29ms/step - loss: 0.2559 - accuracy: 0.9045 - val_loss: 0.2519 - val_accuracy: 0.9144
# Epoch 18/100
# 158/158 [==============================] - 6s 39ms/step - loss: 0.2527 - accuracy: 0.9084 - val_loss: 0.2521 - val_accuracy: 0.9127
# Epoch 19/100
# 158/158 [==============================] - 6s 38ms/step - loss: 0.2478 - accuracy: 0.9076 - val_loss: 0.2313 - val_accuracy: 0.9234
# Epoch 20/100
# 158/158 [==============================] - 5s 33ms/step - loss: 0.2458 - accuracy: 0.9098 - val_loss: 0.2360 - val_accuracy: 0.9180
# Epoch 21/100
# 158/158 [==============================] - 6s 36ms/step - loss: 0.2392 - accuracy: 0.9122 - val_loss: 0.2387 - val_accuracy: 0.9162
# Epoch 22/100
# 158/158 [==============================] - 5s 34ms/step - loss: 0.2390 - accuracy: 0.9090 - val_loss: 0.2362 - val_accuracy: 0.9251
# Epoch 23/100
# 158/158 [==============================] - 6s 35ms/step - loss: 0.2387 - accuracy: 0.9106 - val_loss: 0.2545 - val_accuracy: 0.9162
# Epoch 24/100
# 158/158 [==============================] - 5s 31ms/step - loss: 0.2331 - accuracy: 0.9118 - val_loss: 0.2262 - val_accuracy: 0.9216
# Epoch 25/100
# 158/158 [==============================] - 7s 42ms/step - loss: 0.2327 - accuracy: 0.9106 - val_loss: 0.2302 - val_accuracy: 0.9216
# Epoch 26/100
# 158/158 [==============================] - 6s 37ms/step - loss: 0.2337 - accuracy: 0.9116 - val_loss: 0.2406 - val_accuracy: 0.9180
# Epoch 27/100
# 158/158 [==============================] - 5s 34ms/step - loss: 0.2311 - accuracy: 0.9104 - val_loss: 0.2467 - val_accuracy: 0.9127
# Epoch 28/100
# 158/158 [==============================] - 6s 37ms/step - loss: 0.2310 - accuracy: 0.9162 - val_loss: 0.2301 - val_accuracy: 0.9234
# Epoch 29/100
# 158/158 [==============================] - 5s 33ms/step - loss: 0.2279 - accuracy: 0.9114 - val_loss: 0.2346 - val_accuracy: 0.9216
# Epoch 30/100
# 158/158 [==============================] - 5s 34ms/step - loss: 0.2277 - accuracy: 0.9148 - val_loss: 0.2342 - val_accuracy: 0.9234
# Epoch 31/100
# 158/158 [==============================] - 5s 34ms/step - loss: 0.2290 - accuracy: 0.9152 - val_loss: 0.2313 - val_accuracy: 0.9234
#
# Model Evaluation:
# Accuracy: 0.9322396576319544
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.93      0.94      0.93       700
#            1       0.94      0.92      0.93       702
#
#     accuracy                           0.93      1402
#    macro avg       0.93      0.93      0.93      1402
# weighted avg       0.93      0.93      0.93      1402
# Probability of rain tomorrow: 5.14%
# Prediction: It will NOT rain tomorrow
